# %%
df = read_data('big_run2_times.txt')
df
plt.plot_date(df['time'][:], df['number'][:], linestyle='solid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 df = read_data('big_run2_times.txt')
#       2 df
# ----> 3 plt.plot(df['time'][:], df['number'][:], linestyle='solid')
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from dateutil import parser

def read_data(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Extract the numbers and timestamps alternatively
    numbers = [int(lines[i]) for i in range(0, len(lines), 2)]
    timestamps = [parser.parse(lines[i].strip()) for i in range(1, len(lines), 2)]

    return pd.DataFrame({'time': timestamps, 'number': numbers})

def plot_data(df):
    plt.figure(figsize=(10,6))
    plt.plot_date(df['time'], df['number'], linestyle='solid')
    plt.title('Number as a Function of Time')
    plt.xlabel('Time')
    plt.ylabel('Number')
    plt.tight_layout()
    plt.show()

# Usage
df = read_data('big_run2.txt')
plot_data(df)
# Out:
# /tmp/ipykernel_30546/2013067311.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 26
#      24 # Usage
#      25 df = read_data('big_run2_times.txt')
# ---> 26 plot_data(df)
#
# Cell In[1], line 17, in plot_data(df)
#      15 def plot_data(df):
#      16     plt.figure(figsize=(10,6))
# ---> 17     plt.plot_date(df['time'], df['number'], linestyle='solid')
#      18     plt.title('Number as a Function of Time')
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
from dateutil import parser
from sklearn.linear_model import LinearRegression
from datetime import timedelta

def read_data(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    numbers = [int(lines[i]) for i in range(0, len(lines), 2)]
    timestamps = [parser.parse(lines[i].strip()) for i in range(1, len(lines), 2)]

    return pd.DataFrame({'time': timestamps, 'number': numbers})

def fit_data(df):
    df['time_numeric'] = df['time'].map(mdates.date2num)

    model = LinearRegression()
    model.fit(df['time_numeric'].values.reshape(-1, 1), df['number'])

    return model

def get_zero_time(df, model):
    # Find the date when the value will be zero
    zero_date = mdates.num2date(-(model.intercept_ / model.coef_[0]))
    return zero_date

def plot_data(df, model, zero_date):
    plt.figure(figsize=(10,6))

    # Plot the original data
    plt.plot_date(df['time'], df['number'], linestyle='solid', linewidth=3, marker='o', markersize=10)

    # Prepare dates for the fitted line
    line_dates = np.linspace(df['time_numeric'].min(), mdates.date2num(zero_date), 100)
    line_dates = mdates.num2date(line_dates)

    # Predict the values for the fitted line
    line_values = model.predict(np.array([mdates.date2num(date) for date in line_dates]).reshape(-1, 1))

    # Plot the fitted line
    plt.plot(line_dates, line_values, linewidth=3, linestyle='dashed', color='red')

    # Format x-axis to display dates
    locator = mdates.AutoDateLocator(minticks=6, maxticks=10, interval_multiples=True)
    formatter = mdates.ConciseDateFormatter(locator)
    plt.gca().xaxis.set_major_locator(locator)
    plt.gca().xaxis.set_major_formatter(formatter)

    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
    plt.title('Unfinished Jobs on Cluster as a Function of Time', fontsize=18)
    plt.xlabel('Time', fontsize=18)
    plt.ylabel('Unfinished Jobs', fontsize=18)
#     plt.ylim(0, 1200)
    plt.tight_layout()
    plt.show()
    
# Usage
# df = read_data('data.txt')
df = read_data('times_scratch_run.txt')
df['time_numeric'] = df['time'].map(mdates.date2num)
model = fit_data(df)
zero_date = get_zero_time(df, model)
plot_data(df, model, zero_date)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname CEST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# C:\Users\user\AppData\Local\Temp\ipykernel_25680\323581841.py:35: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(df['time'], df['number'], linestyle='solid', linewidth=3, marker='o', markersize=10)
